# %% [markdown]
# # How high of an incentive (measured through differences in overall GPA) do students face by enrolling in classes with relatively higher grade distributions?
#
#
# ## Diego Saldonid, PID: A12012095
# ## Roger Ruan, PID: A11186574
# ## Shu-Wei(Lucas) Hsu, PID: A12961177
# ## James Mata, PID: A12462782

# %% [markdown]
# ## Introduction and Background
#
# With grade inflation becoming a growing problem between public and private school we were interested in taking a closer look to see what may be happening within a school. As students, we often hear advice on which professor to take for a certain class because the chances of getting a good grade are higher. For many students at UCSD, who plan to pursue careers that involve more education or careers in their subject’s job market, GPA is an important factor to look competitive in these fields. This leads students to wait for a class to be taught by a certain professor in order to boost their transcripts and have a higher chance at success. This leads us to our questions:
#
# * **What would be the difference in GPA between students that happen to take professors with lower grade distributions relative to their fellow professors?**
# * **If we are able to find a large enough disparity between these students, what would be our call to action?**
# * **Furthermore, what might this reflect on the way classes are being taught, not only at UCSD but at other Universities?**
#
# As our reference allude to, just because they are getting higher grades does not imply that students are performing higher or learning more. The growing competition to get into medical school, grad school, or other competitive career fields incentives students to pursue a higher grade over leaving college with technical skills and knowledge. Also, are the classes with higher distribution, are they not challenging students as much or do they provide a better teaching environment?

# %% [markdown]
# ## Data Description
#
# The dataset used for our project is the UCSD Cape Evaluations, found at https://cape.ucsd.edu/responses/Results.aspx. This dataset has grade distributions for various classes among multiple disciplines at UCSD from Spring quarter 2007 to Spring Quarter 2017. We will be focusing on the following select majors:
#
# * Cognitive Science
# * Biology
# * Biochemistry
# * Mechnical and Aerospace Engineering
# * Chemistry
# * Computer Science
#
# From these majors, we will be analyzing required major courses.
#
# Each data row has the following columns:
#
# * Professor/Instructor
# * Course
# * Term
# * Number of Enrollment
# * Number of Evaluations Made
# * Recommended Class
# * Recommended Instructor
# * Study Hours/week
# * Average Grade Expected
# * Average Grade Received
#
# After cleaning our data, we will be focusing on Instructor, Course, Term, Rcmnd Instr, Study Hrs/wk, and Avg Grade Received.
#
# By comparing different students across different professors taken at different times we will be able to analyze any changes between professors as well as pick up on any trends that are happening within a certain department. By tracking the changes across multiple departments (to have an accurate representation of what is happening campus wide) we can compare how changes at UCSD agree or disagree with national trends. We will also compare the amount of study hours between the courses taught by professors of the same department, this will serve as an indicator on how rigorous classes may be, which may point to the differences in grade distributions.
#
# After scraping the data, we disregard ones with NaN rows and data where the number of evaluations made for the class is under 40%.

# %% [markdown]
# Loading modules. We are using the beautiful soup library to scrap through different categories that are given with evaluations.

# %%
import ssl
import urllib.request
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# Here, we are setting up the dataframe for the data we are going to scrap. We create a function called scrapData that goes through the online dataset with a specified major and extract the data onto our dataframe. We create a variable of the column values and then create a dataframe using the implemented column variables.

# %%
#all courses
def scrapData(links, i, dfT):
    gcontext = ssl.SSLContext(ssl.PROTOCOL_TLSv1)
    req = urllib.request.Request(url="https://cape.ucsd.edu/responses/Results.aspx?Name=&CourseNumber=" + links[i],
        data=b'None',headers={'User-Agent':' Mozilla/5.0 (Windows NT 6.1; WOW64; rv:12.0) Gecko/20100101 Firefox/12.0'})
    handler = urllib.request.urlopen(req, context=gcontext)
    htmltext = handler.read()
    soup = BeautifulSoup(htmltext,'lxml')

    # Create four variables to score the scraped data in
    Name = []
    course = []
    courseNum = []
    rcmndClass = []
    term = []
    enroll = []
    evalMade = []
    rcmndInstructor = []
    studyHrs = []
    avgGradeExpected = []
    avgGradeRecieved = []

    # Create an object of the first object that is class=dataframe
    table = soup.find(class_='styled')

    # Find all the <tr> tag pairs, skip the first one, then for each.
    for row in table.find_all('tr')[1:]:

        spans = row.find_all('span')
        a = row.find_all('a')

        # Create a variable of all the <td> tag pairs in each <tr> tag pair,
        col = row.find_all('td')

        # Create a variable of the string inside 1st <td> tag pair,
        column_1 = col[0].string
        # and append it to first_name variable
        Name.append(column_1)

        #find class name
        column_10 = a[0].text
        course.append(column_10)

        column_11 = a[0].text
        x = column_11.split("-")[0]
        x = x.split(" ")[1]
        courseNum.append(x)
        
        # Create a variable of the string inside 2nd <td> tag pair,
        column_2 = spans[1].text
        # and append it to last_name variable
        rcmndClass.append(column_2)

        # Create a variable of the string inside 3rd <td> tag pair,
        column_3 = col[2].string
        # and append it to age variable
        term.append(column_3)

        # Create a variable of the string inside 4th <td> tag pair,
        column_4 = col[3].text
        # and append it to enroll variable
        enroll.append(column_4)

        # Create a variable of the string inside 5th <td> tag pair,
        column_5 = spans[0].text
        # and append it to postTestScore variable
        evalMade.append(column_5)

        column_6 = spans[2].text
        rcmndInstructor.append(column_6)

        column_7 = spans[3].text
        studyHrs.append(column_7)

        column_8 = spans[4].text
        avgGradeExpected.append(column_8)

        column_9 = spans[5].text
        avgGradeRecieved.append(column_9)

    # Create a variable of the value of the columns
    columns = {'Name': Name, 'rcmndClass': rcmndClass, 'term': term, 'enroll': enroll, 'evalMade': evalMade, 
               'rcmndInstructor':rcmndInstructor, 'studyHrs':studyHrs, 'avgGradeExpected':avgGradeExpected 
               ,'avgGradeRecieved':avgGradeRecieved, 'course':course, 'courseNum': courseNum}

    # Create a dataframe from the columns variable
    df = pd.DataFrame(columns)
    df = df[['Name', 'course', 'courseNum','term', 'enroll', 'evalMade', 'rcmndClass', 'rcmndInstructor','studyHrs', 
             'avgGradeExpected', 'avgGradeRecieved' ]]
    return df

# %% [markdown]
# Right now, we're focusing on data relating to the cogs major and the core classes needed.
# **We will do so for other majors(Cognitive Science, Biology, Biochemistry, Mechnical and Aerospace Engineering, Chemistry, Computer Science) as well!**
# We extract the data for the cogs major by scraping the data for each required course and the different professors that teach each course. We fill our dataframe using the scrapData function created above to give us raw data.

# %%
#links = ['MATH+20B', 'MATH+20A']
cogsMajor = ['MATH+20A', 'MATH+20B','MATH+20C','MATH+20F','COGS+1','COGS+14A',
             'COGS+101A','COGS+102A','COGS+107A','CSE+7']
dfTemp = pd.DataFrame()
dfT = pd.DataFrame();
for i in range(len(cogsMajor)):
    dfTemp = scrapData(cogsMajor,i, dfT)
    dfT = dfT.append(dfTemp)

# %% [markdown]
# ## Data Cleaning/Pre-processing
#
# The data we got above is raw data. We have to clean it now by omitting rows where the grade is not available. To make sure the data points hold significance, we remove rows where the number of evaluations made is less than 40%. This allows a more accurate representation of grade distribution among students.

# %%
#converts the strings from enroll and evalMade to int
dfT.enroll = pd.to_numeric(dfT.enroll)
dfT.evalMade = pd.to_numeric(dfT.evalMade)
#drops classes with N/a grade distributions 
dfT = dfT[dfT.avgGradeRecieved != 'N/A'] 
#drops classes with less than 40% evals made
dfT = dfT[dfT.evalMade/dfT.enroll > .40]
dfT = dfT.reset_index(drop=True)

#print(dfT['courseNum'])
cogsClassNum = ['20A', '20B', '20C', '20F', '1' , '14A' , '101A' , '102A' , '107A', '7']
dfT = dfT[dfT['courseNum'].isin(cogsClassNum)]
dfT
# Out:
#                                     Name  \
# 0                  Stevens, Laura Jeanne
# 1                            Um, Ko Woon
# 2                   Dewey, Edward Harold
# 3                        Bowers, Adam R.
# 4                  Quarfoot, David James
# 5                            Um, Ko Woon
# 6                       Bach, Quang Tran
# 7               Rhoades, Brendon Patrick
# 8                               Wang, Xu
# 9                        Bowers, Adam R.
# 10                       Bowers, Adam R.
# 11                     Novak, Jonathan I
# 12                        Buss, Samuel R
# 13                        Jiang, Zonglin
# 14             Bacellar Dos Santo, Jorge
# 15                        Wang, Xingting
# 16                             Wang, Jie
# 17                       Bowers, Adam R.
# 18                   Bryan, Paul Anthony
# 19                        Wang, Xingting
# 20                         Gaddis, Jason
# 21                        Meier, Caleb A
# 22                 Stevens, Laura Jeanne
# 23                           Saab, Rayan
# 24                         Hall, James B
# 25              Rhoades, Brendon Patrick
# 26                    Hummon, Benjamin T
# 27                 Nelson, Christopher S
# 28                        Zhao, Yanxiang
# 29                 Eggers, John Dietrich
# ..                                   ...
# 366                Barrera, Steven James
# 367                Barrera, Steven James
# 368  Johnson, Christine M.
# 369  Johnson, Christine M.
# 370  Johnson, Christine M.
# 371                 Groppe, David Martin
# 372       Groppe, David Martin
# 373                  Renner, Nancy Owens
# 374                     Marghetis, Tyler
# 375                  Hutchins, Edwin Lee
# 376  Hutchins, Edwin Lee
# 377  Hutchins, Edwin Lee
# 378  Hutchins, Edwin Lee
# 379  Forster, Deborah
# 380       Hutchins, Edwin Lee
# 381                    Boyle, Mary E. T.
# 382                      Pineda, Jaime A
# 383                      Pineda, Jaime A
# 384  Pineda, Jaime A
# 385  Pineda, Jaime A
# 386  Pineda, Jaime A
# 387  Pineda, Jaime A
# 388       Pineda, Jaime A
# 389                        Marx, Susan S
# 390                         Gupta, Anjum
# 391                        Marx, Susan S
# 392                        Marx, Susan S
# 393                        Marx, Susan S
# 394                  Lee, Cynthia Bailey
# 395  Lee, Cynthia Bailey
#
#                                               course courseNum  term  enroll  \
# 0      MATH 20A - Calculus/Science & Engineering (A)       20A  WI17     150
# 1      MATH 20A - Calculus/Science & Engineering (B)       20A  WI17     110
# 2      MATH 20A - Calculus/Science & Engineering (A)       20A  FA16     262
# 3      MATH 20A - Calculus/Science & Engineering (B)       20A  FA16     191
# 4      MATH 20A - Calculus/Science & Engineering (C)       20A  FA16     214
# 5      MATH 20A - Calculus/Science & Engineering (D)       20A  FA16     198
# 6      MATH 20A - Calculus/Science & Engineering (A)       20A  S216      27
# 7      MATH 20A - Calculus/Science & Engineering (A)       20A  SP16      97
# 8      MATH 20A - Calculus/Science & Engineering (A)       20A  WI16      72
# 9      MATH 20A - Calculus/Science & Engineering (B)       20A  WI16     144
# 10     MATH 20A - Calculus/Science & Engineering (A)       20A  FA15     321
# 11     MATH 20A - Calculus/Science & Engineering (B)       20A  FA15     193
# 12     MATH 20A - Calculus/Science & Engineering (C)       20A  FA15     205
# 13     MATH 20A - Calculus/Science & Engineering (D)       20A  FA15     165
# 14     MATH 20A - Calculus/Science & Engineering (A)       20A  WI15      59
# 15     MATH 20A - Calculus/Science & Engineering (B)       20A  WI15     184
# 16     MATH 20A - Calculus/Science & Engineering (A)       20A  FA14     144
# 17     MATH 20A - Calculus/Science & Engineering (B)       20A  FA14     397
# 18     MATH 20A - Calculus/Science & Engineering (C)       20A  FA14     186
# 19     MATH 20A - Calculus/Science & Engineering (D)       20A  FA14     138
# 20     MATH 20A - Calculus/Science & Engineering (A)       20A  WI14     192
# 21     MATH 20A - Calculus/Science & Engineering (B)       20A  WI14     142
# 22     MATH 20A - Calculus/Science & Engineering (A)       20A  FA13     308
# 23     MATH 20A - Calculus/Science & Engineering (B)       20A  FA13     209
# 24     MATH 20A - Calculus/Science & Engineering (C)       20A  FA13     236
# 25     MATH 20A - Calculus/Science & Engineering (D)       20A  FA13     213
# 26     MATH 20A - Calculus/Science & Engineering (A)       20A  WI13     194
# 27     MATH 20A - Calculus/Science & Engineering (B)       20A  WI13     172
# 28     MATH 20A - Calculus/Science & Engineering (A)       20A  FA12     205
# 29     MATH 20A - Calculus/Science & Engineering (B)       20A  FA12     330
# ..                                               ...       ...   ...     ...
# 366         COGS 101A - Sensation and Perception (A)      101A  S213      28
# 367         COGS 101A - Sensation and Perception (A)      101A  FA12     296
# 368  COGS 101A  - Sensation and Perception       (A)      101A  FA11     223
# 369  COGS 101A  - Sensation and Perception       (A)      101A  FA10     165
# 370  COGS 101A  - Sensation and Perception       (A)      101A  FA09     157
# 371  COGS 101A  - Sensation and Perception       (A)      101A  WI09     187
# 372  COGS 101A  - Sensation and Perception       (A)      101A  FA07     117
# 373            COGS 102A - Distributed Cognition (A)      102A  FA15     201
# 374            COGS 102A - Distributed Cognition (A)      102A  FA14     167
# 375            COGS 102A - Distributed Cognition (A)      102A  FA13     170
# 376  COGS 102A  - Distributed Cognition          (A)      102A  FA11     214
# 377  COGS 102A  - Distributed Cognition          (A)      102A  FA10     177
# 378  COGS 102A  - Distributed Cognition          (A)      102A  FA09     154
# 379  COGS 102A  - Distributed Cognition          (A)      102A  FA08     140
# 380  COGS 102A  - Distributed Cognition          (A)      102A  FA07     148
# 381      COGS 107A - Neuroanatomy and Physiology (B)      107A  FA16     304
# 382      COGS 107A - Neuroanatomy and Physiology (A)      107A  FA15     217
# 383      COGS 107A - Neuroanatomy and Physiology (A)      107A  FA13     206
# 384  COGS 107A  - Neuroanatomy and Physiology    (A)      107A  FA11     233
# 385  COGS 107A  - Neuroanatomy and Physiology    (A)      107A  FA10     206
# 386  COGS 107A  - Neuroanatomy and Physiology    (A)      107A  FA09     168
# 387  COGS 107A  - Neuroanatomy and Physiology    (A)      107A  FA08     187
# 388  COGS 107A  - Neuroanatomy and Physiology    (A)      107A  FA07     150
# 389             CSE 7 - Intro Programming MATLAB (A)         7  WI17     130
# 390             CSE 7 - Intro Programming MATLAB (A)         7  S216      45
# 391             CSE 7 - Intro Programming MATLAB (A)         7  SP16     133
# 392             CSE 7 - Intro Programming MATLAB (A)         7  WI16     130
# 393             CSE 7 - Intro Programming MATLAB (A)         7  WI14     100
# 394             CSE 7 - Intro Programming MATLAB (A)         7  WI13     138
# 395     CSE 7   - Intro Programming MATLAB       (A)         7  WI12     100
#
#      evalMade rcmndClass rcmndInstructor studyHrs avgGradeExpected  \
# 0          85     97.5 %         100.0 %     5.48         B (3.30)
# 1          49     70.5 %          65.9 %     6.45        B- (2.84)
# 2         137     93.9 %          85.6 %     6.12        B+ (3.50)
# 3          89     96.5 %          97.6 %     6.70         B (3.23)
# 4         121     99.1 %          97.4 %     5.75        B+ (3.49)
# 5          94     94.3 %          67.0 %     5.55        B+ (3.49)
# 6          18     94.4 %          83.3 %     7.39        B+ (3.33)
# 7          61     93.1 %          93.1 %     5.57         B (3.19)
# 8          30     78.6 %          14.3 %     5.50        C+ (2.54)
# 9          71     95.5 %          95.5 %     6.02        B+ (3.35)
# 10        165     98.7 %         100.0 %     5.81        B+ (3.48)
# 11         86     91.4 %          75.3 %     4.63        B+ (3.53)
# 12        101     94.7 %          86.3 %     5.65        B+ (3.35)
# 13         88     96.5 %          69.8 %     5.58        B+ (3.58)
# 14         27     88.0 %          48.0 %     6.08        B- (2.88)
# 15         84     93.8 %          86.3 %     6.24         B (3.20)
# 16         69     95.2 %          83.9 %     6.08        B+ (3.61)
# 17        211     97.9 %          99.5 %     6.19        B+ (3.64)
# 18         83     93.3 %          74.7 %     4.81        B+ (3.65)
# 19         74     92.6 %          70.6 %     5.27        B+ (3.62)
# 20         85     81.9 %          57.8 %     6.55        B- (2.80)
# 21         77     91.7 %          94.4 %     6.39         B (3.07)
# 22        168     97.5 %          98.1 %     5.23        B+ (3.55)
# 23        119     97.4 %          91.2 %     5.69         B (3.12)
# 24        138     94.1 %          76.5 %     5.84        B+ (3.41)
# 25        133     99.2 %          95.4 %     5.69        B+ (3.56)
# 26         82     85.2 %          79.0 %     6.47        B- (2.89)
# 27        134     91.7 %          72.9 %     5.75         B (3.18)
# 28        103     94.9 %          86.7 %     5.63        B+ (3.35)
# 29        154     93.8 %          91.1 %     6.04         B (3.24)
# ..        ...        ...             ...      ...              ...
# 366        15     93.3 %         100.0 %     6.23        B+ (3.53)
# 367       146     97.7 %          97.7 %     5.01        B+ (3.50)
# 368        97     94.8 %          95.9 %     5.20        B+ (3.45)
# 369       102     90.2 %          94.1 %     5.34        B+ (3.43)
# 370       118     93.2 %          92.3 %     4.19        B+ (3.44)
# 371        98     95.8 %          90.6 %     4.85        B+ (3.41)
# 372        70     95.6 %          79.1 %     4.73        B+ (3.32)
# 373       125     78.0 %          81.3 %     5.28        B+ (3.34)
# 374        69     85.2 %          93.4 %     5.57        B+ (3.43)
# 375        73     53.8 %          76.9 %     5.16        B+ (3.31)
# 376        95     54.8 %          62.4 %     5.62        B+ (3.38)
# 377       116     62.9 %          81.9 %     5.60         B (3.25)
# 378        78     68.8 %          87.0 %     5.03        B+ (3.46)
# 379        91     49.4 %          51.1 %     4.39        B+ (3.55)
# 380        88     75.9 %          95.2 %     4.57        B+ (3.38)
# 381       160     83.0 %          58.8 %     9.49         B (3.09)
# 382       139     92.6 %          89.0 %     5.55        B+ (3.42)
# 383        89     89.0 %          85.4 %     6.16         B (3.01)
# 384       101     94.1 %          94.1 %     6.80         B (3.29)
# 385       164     90.2 %          90.1 %     6.76         B (3.10)
# 386       112     90.9 %          89.3 %     5.40         B (3.16)
# 387       142     93.4 %          95.6 %     6.21        B+ (3.31)
# 388        91     92.0 %          95.5 %     5.26         B (3.28)
# 389        55     83.0 %          73.6 %     3.65        B+ (3.42)
# 390        27     88.0 %          88.0 %     7.92        A- (3.76)
# 391        57     84.6 %          76.9 %     4.85        B+ (3.51)
# 392        62     84.7 %          67.8 %     4.03        B+ (3.44)
# 393        41     76.3 %          63.2 %     3.66        B+ (3.43)
# 394        61     86.9 %          96.7 %     5.61        A- (3.77)
# 395        64     87.5 %          92.2 %     6.34        B+ (3.34)
#
#     avgGradeRecieved
# 0          C+ (2.51)
# 1          C+ (2.36)
# 2          B- (2.87)
# 3          C+ (2.38)
# 4          C+ (2.50)
# 5          C+ (2.51)
# 6           B (3.29)
# 7          B- (2.83)
# 8          B- (2.93)
# 9          C+ (2.40)
# 10         B- (2.81)
# 11         B- (2.92)
# 12         B- (2.91)
# 13          B (3.04)
# 14         C+ (2.36)
# 15         B+ (3.45)
# 16         B- (2.85)
# 17          B (3.17)
# 18          B (3.17)
# 19         B- (2.86)
# 20         C- (1.87)
# 21         C+ (2.50)
# 22         B- (2.72)
# 23         C+ (2.53)
# 24         C+ (2.62)
# 25          B (3.02)
# 26         C+ (2.43)
# 27         C+ (2.68)
# 28         C+ (2.41)
# 29         C+ (2.39)
# ..               ...
# 366        B+ (3.39)
# 367         B (3.15)
# 368         B (3.05)
# 369         B (3.02)
# 370        B- (2.88)
# 371        B- (2.83)
# 372        C+ (2.68)
# 373        B+ (3.55)
# 374        B+ (3.33)
# 375         B (3.25)
# 376         B (3.14)
# 377         B (3.11)
# 378         B (3.21)
# 379        B+ (3.33)
# 380         B (3.08)
# 381         B (3.19)
# 382        B- (2.99)
# 383        B- (2.91)
# 384        B- (2.95)
# 385        B- (2.79)
# 386        B- (2.83)
# 387        B- (2.86)
# 388        B- (2.82)
# 389         B (3.24)
# 390        B+ (3.47)
# 391         B (3.22)
# 392         B (3.21)
# 393        B+ (3.50)
# 394        B+ (3.38)
# 395        B- (2.95)
#
# [396 rows x 11 columns]

# %% [markdown]
# ## Data Analysis and Results
#
# With this data we will be able to track changes in student GPA for the last ten years. We will compare changes in GPA across departments, we can see if UCSD follows national trends while keeping our datapool campus wide. Comparing study hours bewteen the courses taught by professors of the same department allows us to analyze study methods as a descrepency. Ultimately, we are looking to see if students who take professors with higher grade distributions and students who take professors with lower grade distributions and see how much of an impact the difference in professors have on students' overall GPA.

# %%
#initialize maximum possible GPA
maxGpa = []
minGpa = []

# %%
cogsClassNum = ['20A', '20B', '20C', '20F', '1' , '14A' , '101A' , '102A' , '107A', '7']

def gpaValue (classes, i, df):
    #get the data and clean it
    course = scrapData(classes,i, df)
    course.enroll = pd.to_numeric(course.enroll)
    course.evalMade = pd.to_numeric(course.evalMade)
    course = course[course.avgGradeRecieved != 'N/A'] 

    #print(course)
    #drops classes with less than 40% evals made
    course = course[course.evalMade/course.enroll > .40]
    #reset index
    course = course.reset_index(drop=True)
    #print(course['courseNum'] == )
    
    course = course[course['courseNum'].isin(cogsClassNum)]
    course = course.reset_index(drop=True)
    
    for k in range(len(course['avgGradeRecieved'])):
        x = course['avgGradeRecieved'][k]
        #split string in order to get rid of letters
        x = x.split("(")[1]
        x = x.split(')')[0]
        #set value to only number
        course.loc[k,('avgGradeRecieved')] = x

    #set to numeric value
    course.avgGradeRecieved = pd.to_numeric(course.avgGradeRecieved)

    #get the maximum value
    rowMax = course['avgGradeRecieved'].idxmax()
    rowMin = course['avgGradeRecieved'].idxmin()

    #get the GPA and format it in hundreds
    maxGpa.append(math.ceil((course['avgGradeRecieved'][rowMax])*100)/100)
    minGpa.append(math.ceil((course['avgGradeRecieved'][rowMin])*100)/100)

# %%
#get gpa values for all classes
df_1 = pd.DataFrame();
for i in range(len(cogsMajor)):
    gpaValue(cogsMajor, i, df_1)
# Out:
#                                    Name  \
# 0                 Stevens, Laura Jeanne
# 1                           Um, Ko Woon
# 2                  Dewey, Edward Harold
# 3                       Bowers, Adam R.
# 4                 Quarfoot, David James
# 5                           Um, Ko Woon
# 6                      Bach, Quang Tran
# 7              Rhoades, Brendon Patrick
# 8                              Wang, Xu
# 9                       Bowers, Adam R.
# 10                      Bowers, Adam R.
# 11                    Novak, Jonathan I
# 12                       Buss, Samuel R
# 13                       Jiang, Zonglin
# 14            Bacellar Dos Santo, Jorge
# 15                       Wang, Xingting
# 16                            Wang, Jie
# 17                      Bowers, Adam R.
# 18                  Bryan, Paul Anthony
# 19                       Wang, Xingting
# 20                        Gaddis, Jason
# 21                       Meier, Caleb A
# 22                Stevens, Laura Jeanne
# 23                          Saab, Rayan
# 24                        Hall, James B
# 25             Rhoades, Brendon Patrick
# 26                   Hummon, Benjamin T
# 27                Nelson, Christopher S
# 28                       Zhao, Yanxiang
# 29                Eggers, John Dietrich
# 30        Kenter, Franklin Hardin Jones
# 31                   Nguyen, Nicholas D
# 32  Minor, Andre J
# 33  Weinkove, Benjamin
# 34  Bowers, Adam R.
# 35  Vankerschaver, Joris G
# 36  Weinkove, Benjamin
# 37  Eggers, John Dietrich
# 38  Yip, Martha
# 39  Zhang, Yuan
# 40  Kong, Shengli
# 41  Yoo, Meesue
# 42  Zhang, Yuan
# 43  Eggers, John Dietrich
# 44  Yoo, Meesue
# 45  Abramson, Ian S
# 46  Eldredge, Nathaniel Gilbert Bartsch
# 47                   Szypowski, Ryan S.
# 48  Eggers, John Dietrich
# 49  Baouendi, M Salah
# 50       Mohanty, Yana Z
# 51       Lunasin, Evelyn Manalo
# 52       Lev, Vsevolod
# 53       Linshaw, Andrew Ross
#
#                                             course courseNum  term  enroll  \
# 0    MATH 20A - Calculus/Science & Engineering (A)       20A  WI17     150
# 1    MATH 20A - Calculus/Science & Engineering (B)       20A  WI17     110
# 2    MATH 20A - Calculus/Science & Engineering (A)       20A  FA16     262
# 3    MATH 20A - Calculus/Science & Engineering (B)       20A  FA16     191
# 4    MATH 20A - Calculus/Science & Engineering (C)       20A  FA16     214
# 5    MATH 20A - Calculus/Science & Engineering (D)       20A  FA16     198
# 6    MATH 20A - Calculus/Science & Engineering (A)       20A  S216      27
# 7    MATH 20A - Calculus/Science & Engineering (A)       20A  SP16      97
# 8    MATH 20A - Calculus/Science & Engineering (A)       20A  WI16      72
# 9    MATH 20A - Calculus/Science & Engineering (B)       20A  WI16     144
# 10   MATH 20A - Calculus/Science & Engineering (A)       20A  FA15     321
# 11   MATH 20A - Calculus/Science & Engineering (B)       20A  FA15     193
# 12   MATH 20A - Calculus/Science & Engineering (C)       20A  FA15     205
# 13   MATH 20A - Calculus/Science & Engineering (D)       20A  FA15     165
# 14   MATH 20A - Calculus/Science & Engineering (A)       20A  WI15      59
# 15   MATH 20A - Calculus/Science & Engineering (B)       20A  WI15     184
# 16   MATH 20A - Calculus/Science & Engineering (A)       20A  FA14     144
# 17   MATH 20A - Calculus/Science & Engineering (B)       20A  FA14     397
# 18   MATH 20A - Calculus/Science & Engineering (C)       20A  FA14     186
# 19   MATH 20A - Calculus/Science & Engineering (D)       20A  FA14     138
# 20   MATH 20A - Calculus/Science & Engineering (A)       20A  WI14     192
# 21   MATH 20A - Calculus/Science & Engineering (B)       20A  WI14     142
# 22   MATH 20A - Calculus/Science & Engineering (A)       20A  FA13     308
# 23   MATH 20A - Calculus/Science & Engineering (B)       20A  FA13     209
# 24   MATH 20A - Calculus/Science & Engineering (C)       20A  FA13     236
# 25   MATH 20A - Calculus/Science & Engineering (D)       20A  FA13     213
# 26   MATH 20A - Calculus/Science & Engineering (A)       20A  WI13     194
# 27   MATH 20A - Calculus/Science & Engineering (B)       20A  WI13     172
# 28   MATH 20A - Calculus/Science & Engineering (A)       20A  FA12     205
# 29   MATH 20A - Calculus/Science & Engineering (B)       20A  FA12     330
# 30   MATH 20A - Calculus/Science & Engineering (C)       20A  FA12     211
# 31   MATH 20A - Calculus/Science & Engineering (D)       20A  FA12     169
# 32  MATH 20A  - Calculus/Science & Engineering (A)       20A  WI12     277
# 33  MATH 20A  - Calculus/Science & Engineering (A)       20A  FA11     196
# 34  MATH 20A  - Calculus/Science & Engineering (B)       20A  FA11     293
# 35  MATH 20A  - Calculus/Science & Engineering (D)       20A  FA11     211
# 36  MATH 20A  - Calculus/Science & Engineering (A)       20A  WI11     277
# 37  MATH 20A  - Calculus/Science & Engineering (A)       20A  FA10     284
# 38  MATH 20A  - Calculus/Science & Engineering (B)       20A  FA10     187
# 39  MATH 20A  - Calculus/Science & Engineering (C)       20A  FA10     207
# 40  MATH 20A  - Calculus/Science & Engineering (A)       20A  SP10      92
# 41  MATH 20A  - Calculus/Science & Engineering (A)       20A  WI10     219
# 42  MATH 20A  - Calculus/Science & Engineering (A)       20A  FA09     104
# 43  MATH 20A  - Calculus/Science & Engineering (B)       20A  FA09     188
# 44  MATH 20A  - Calculus/Science & Engineering (C)       20A  FA09     166
# 45  MATH 20A  - Calculus/Science & Engineering (D)       20A  FA09     170
# 46  MATH 20A  - Calculus/Science & Engineering (A)       20A  SP09      96
# 47  MATH 20A  - Calculus/Science & Engineering (A)       20A  WI09     212
# 48  MATH 20A  - Calculus/Science & Engineering (A)       20A  FA08     193
# 49  MATH 20A  - Calculus/Science & Engineering (B)       20A  FA08     183
# 50  MATH 20A  - Calculus/Science & Engineering (A)       20A  WI08     265
# 51  MATH 20A  - Calculus/Science & Engineering (B)       20A  FA07     156
# 52  MATH 20A  - Calculus/Science & Engineering (C)       20A  FA07     147
# 53  MATH 20A  - Calculus/Science & Engineering (D)       20A  FA07     168
#
#     evalMade rcmndClass rcmndInstructor studyHrs avgGradeExpected  \
# 0         85     97.5 %         100.0 %     5.48         B (3.30)
# 1         49     70.5 %          65.9 %     6.45        B- (2.84)
# 2        137     93.9 %          85.6 %     6.12        B+ (3.50)
# 3         89     96.5 %          97.6 %     6.70         B (3.23)
# 4        121     99.1 %          97.4 %     5.75        B+ (3.49)
# 5         94     94.3 %          67.0 %     5.55        B+ (3.49)
# 6         18     94.4 %          83.3 %     7.39        B+ (3.33)
# 7         61     93.1 %          93.1 %     5.57         B (3.19)
# 8         30     78.6 %          14.3 %     5.50        C+ (2.54)
# 9         71     95.5 %          95.5 %     6.02        B+ (3.35)
# 10       165     98.7 %         100.0 %     5.81        B+ (3.48)
# 11        86     91.4 %          75.3 %     4.63        B+ (3.53)
# 12       101     94.7 %          86.3 %     5.65        B+ (3.35)
# 13        88     96.5 %          69.8 %     5.58        B+ (3.58)
# 14        27     88.0 %          48.0 %     6.08        B- (2.88)
# 15        84     93.8 %          86.3 %     6.24         B (3.20)
# 16        69     95.2 %          83.9 %     6.08        B+ (3.61)
# 17       211     97.9 %          99.5 %     6.19        B+ (3.64)
# 18        83     93.3 %          74.7 %     4.81        B+ (3.65)
# 19        74     92.6 %          70.6 %     5.27        B+ (3.62)
# 20        85     81.9 %          57.8 %     6.55        B- (2.80)
# 21        77     91.7 %          94.4 %     6.39         B (3.07)
# 22       168     97.5 %          98.1 %     5.23        B+ (3.55)
# 23       119     97.4 %          91.2 %     5.69         B (3.12)
# 24       138     94.1 %          76.5 %     5.84        B+ (3.41)
# 25       133     99.2 %          95.4 %     5.69        B+ (3.56)
# 26        82     85.2 %          79.0 %     6.47        B- (2.89)
# 27       134     91.7 %          72.9 %     5.75         B (3.18)
# 28       103     94.9 %          86.7 %     5.63        B+ (3.35)
# 29       154     93.8 %          91.1 %     6.04         B (3.24)
# 30        96     94.2 %          89.5 %     6.17        B+ (3.51)
# 31        91     97.6 %          84.7 %     5.57         B (3.23)
# 32       119     94.0 %          85.6 %     6.45         B (3.21)
# 33       115     95.7 %         100.0 %     5.20        B+ (3.45)
# 34       168     97.6 %          98.2 %     5.83        B+ (3.55)
# 35       133     98.5 %          88.0 %     5.97        B+ (3.47)
# 36       143     98.6 %          95.8 %     5.70         B (3.24)
# 37       171     94.1 %          94.0 %     6.94         B (3.17)
# 38       120     89.0 %          82.2 %     6.18         B (3.15)
# 39       113     90.3 %          39.3 %     5.63         B (3.23)
# 40        38     92.1 %          86.1 %     6.08         B (3.14)
# 41       113     85.0 %          36.3 %     7.29        B- (2.92)
# 42        48     93.8 %          57.4 %     5.71        B+ (3.36)
# 43       119     95.0 %          93.3 %     5.42         B (3.19)
# 44        97     84.4 %          43.3 %     4.67         B (3.14)
# 45        75     94.5 %          94.5 %     5.22         B (3.23)
# 46        43     82.9 %          70.7 %     5.60        B- (2.84)
# 47       130     88.5 %          94.6 %     5.22         B (3.16)
# 48        78     92.2 %          93.5 %     5.69        B- (2.99)
# 49        97     86.3 %          88.3 %     6.17        B- (2.98)
# 50       131     85.3 %          65.6 %     5.78        B- (2.97)
# 51       116     87.5 %          70.5 %     6.98         B (3.11)
# 52        97     90.5 %          64.6 %     4.54        B- (2.88)
# 53       124     89.4 %          74.6 %     5.29        B- (2.97)
#
#    avgGradeRecieved
# 0         C+ (2.51)
# 1         C+ (2.36)
# 2         B- (2.87)
# 3         C+ (2.38)
# 4         C+ (2.50)
# 5         C+ (2.51)
# 6          B (3.29)
# 7         B- (2.83)
# 8         B- (2.93)
# 9         C+ (2.40)
# 10        B- (2.81)
# 11        B- (2.92)
# 12        B- (2.91)
# 13         B (3.04)
# 14        C+ (2.36)
# 15        B+ (3.45)
# 16        B- (2.85)
# 17         B (3.17)
# 18         B (3.17)
# 19        B- (2.86)
# 20        C- (1.87)
# 21        C+ (2.50)
# 22        B- (2.72)
# 23        C+ (2.53)
# 24        C+ (2.62)
# 25         B (3.02)
# 26        C+ (2.43)
# 27        C+ (2.68)
# 28        C+ (2.41)
# 29        C+ (2.39)
# 30        C+ (2.62)
# 31        C+ (2.63)
# 32        B- (2.70)
# 33        B- (2.74)
# 34        B- (2.95)
# 35        B- (2.89)
# 36        C+ (2.38)
# 37        C+ (2.46)
# 38        C+ (2.46)
# 39        C+ (2.60)
# 40        C+ (2.53)
# 41        B- (2.73)
# 42        C+ (2.59)
# 43         C (2.26)
# 44        B- (2.93)
# 45        C+ (2.68)
# 46        C+ (2.55)
# 47        C+ (2.50)
# 48         C (2.28)
# 49         C (2.26)
# 50         C (2.14)
# 51        B- (2.78)
# 52        C+ (2.43)
# 53        C+ (2.34)
#                                    Name  \
# 0                       Bowers, Adam R.
# 1                        Huynh, Thang L
# 2                  Dewey, Edward Harold
# 3                 Eggers, John Dietrich
# 4                           Um, Ko Woon
# 5            Deotte, Christopher George
# 6                       Buskin, Nikolay
# 7                        Jolany, Hassan
# 8                         Chow, Bennett
# 9                 Rideout, David Porter
# 10                               Li, Bo
# 11           Tiee, Christopher Landrick
# 12                      Bowers, Adam R.
# 13                    Novak, Jonathan I
# 14                      Kim, Yeon Kyung
# 15                   Martirosyan, Lilit
# 16             Barrese, Kenneth William
# 17                        Behzadan, Ali
# 18                          Saab, Rayan
# 19                      Kim, Yeon Kyung
# 20                   Medrano, Archie T.
# 21                  Bryan, Paul Anthony
# 22                         Allen, Grant
# 23                      Bowers, Adam R.
# 24            Banaszak, Grzegorz Marian
# 25                           Wen, Jiayi
# 26                         Izadi, Elham
# 27                Stevens, Laura Jeanne
# 28                         Li, Xiaolong
# 29                             Sun, Hui
# ..                                  ...
# 60  Volpato, Michael
# 61  Dong, Bin
# 62  Lifschitz, Lucy
# 63  Ohsawa, Tomoki
# 64  Mirjalalieh Shirazi, Mir Hamed
# 65  Eggers, John Dietrich
# 66  Young, Stephen J.
# 67  Shingel, Tatiana
# 68  Stevens, Laura Jeanne
# 69  Kong, Shengli
# 70  Shopple, John P.
# 71  Kadison, Lars
# 72  Volpato, Michael
# 73  Volpato, Michael
# 74  Lunasin, Evelyn Manalo
# 75                     Rogalski, Daniel
# 76                Stevens, Laura Jeanne
# 77  Chan, Ping-Shun
# 78  Chow, Bennett
# 79  Linshaw, Andrew Ross
# 80  Tesler, Glenn
# 81  Bucicovschi, Orest
# 82       Stevens, Laura Jeanne
# 83       Eggers, John Dietrich
# 84       Bender, Edward A.
# 85       Kitchloo, Nitya
# 86       Eggers, John Dietrich
# 87       Lunasin, Evelyn Manalo
# 88       Hohnhold, Henning
# 89       Rogalski, Daniel
#
#                                             course courseNum  term  enroll  \
# 0    MATH 20B - Calculus/Science & Engineering (A)       20B  WI17     369
# 1    MATH 20B - Calculus/Science & Engineering (B)       20B  WI17     145
# 2    MATH 20B - Calculus/Science & Engineering (C)       20B  WI17     202
# 3    MATH 20B - Calculus/Science & Engineering (A)       20B  FA16     317
# 4    MATH 20B - Calculus/Science & Engineering (B)       20B  FA16     188
# 5    MATH 20B - Calculus/Science & Engineering (C)       20B  FA16     211
# 6    MATH 20B - Calculus/Science & Engineering (D)       20B  FA16     272
# 7    MATH 20B - Calculus/Science & Engineering (E)       20B  FA16     103
# 8    MATH 20B - Calculus/Science & Engineering (A)       20B  S216      62
# 9    MATH 20B - Calculus/Science & Engineering (A)       20B  S116      53
# 10   MATH 20B - Calculus/Science & Engineering (A)       20B  SP16     209
# 11   MATH 20B - Calculus/Science & Engineering (B)       20B  SP16      90
# 12   MATH 20B - Calculus/Science & Engineering (A)       20B  WI16     318
# 13   MATH 20B - Calculus/Science & Engineering (B)       20B  WI16     259
# 14   MATH 20B - Calculus/Science & Engineering (C)       20B  WI16     196
# 15   MATH 20B - Calculus/Science & Engineering (D)       20B  WI16     167
# 16   MATH 20B - Calculus/Science & Engineering (A)       20B  FA15     272
# 17   MATH 20B - Calculus/Science & Engineering (B)       20B  FA15     238
# 18   MATH 20B - Calculus/Science & Engineering (C)       20B  FA15     224
# 19   MATH 20B - Calculus/Science & Engineering (D)       20B  FA15     214
# 20   MATH 20B - Calculus/Science & Engineering (E)       20B  FA15     215
# 21   MATH 20B - Calculus/Science & Engineering (A)       20B  WI15     168
# 22   MATH 20B - Calculus/Science & Engineering (B)       20B  WI15     213
# 23   MATH 20B - Calculus/Science & Engineering (C)       20B  WI15     384
# 24   MATH 20B - Calculus/Science & Engineering (D)       20B  WI15     121
# 25   MATH 20B - Calculus/Science & Engineering (A)       20B  FA14     176
# 26   MATH 20B - Calculus/Science & Engineering (B)       20B  FA14     205
# 27   MATH 20B - Calculus/Science & Engineering (C)       20B  FA14     274
# 28   MATH 20B - Calculus/Science & Engineering (D)       20B  FA14     222
# 29   MATH 20B - Calculus/Science & Engineering (E)       20B  FA14     215
# ..                                             ...       ...   ...     ...
# 60  MATH 20B  - Calculus/Science & Engineering (C)       20B  WI11     197
# 61  MATH 20B  - Calculus/Science & Engineering (A)       20B  FA10     241
# 62  MATH 20B  - Calculus/Science & Engineering (B)       20B  FA10     277
# 63  MATH 20B  - Calculus/Science & Engineering (C)       20B  FA10     185
# 64  MATH 20B  - Calculus/Science & Engineering (D)       20B  FA10     194
# 65  MATH 20B  - Calculus/Science & Engineering (A)       20B  SP10     287
# 66  MATH 20B  - Calculus/Science & Engineering (A)       20B  WI10     185
# 67  MATH 20B  - Calculus/Science & Engineering (B)       20B  WI10     127
# 68  MATH 20B  - Calculus/Science & Engineering (C)       20B  WI10     380
# 69  MATH 20B  - Calculus/Science & Engineering (A)       20B  FA09     287
# 70  MATH 20B  - Calculus/Science & Engineering (B)       20B  FA09     258
# 71  MATH 20B  - Calculus/Science & Engineering (C)       20B  FA09     192
# 72  MATH 20B  - Calculus/Science & Engineering (D)       20B  FA09     129
# 73  MATH 20B  - Calculus/Science & Engineering (A)       20B  SP09      93
# 74  MATH 20B  - Calculus/Science & Engineering (B)       20B  SP09     177
# 75  MATH 20B  - Calculus/Science & Engineering (A)       20B  WI09     304
# 76  MATH 20B  - Calculus/Science & Engineering (B)       20B  WI09     279
# 77  MATH 20B  - Calculus/Science & Engineering (A)       20B  FA08     233
# 78  MATH 20B  - Calculus/Science & Engineering (B)       20B  FA08     174
# 79  MATH 20B  - Calculus/Science & Engineering (C)       20B  FA08     187
# 80  MATH 20B  - Calculus/Science & Engineering (D)       20B  FA08     195
# 81  MATH 20B  - Calculus/Science & Engineering (E)       20B  FA08     120
# 82  MATH 20B  - Calculus/Science & Engineering (A)       20B  SP08     188
# 83  MATH 20B  - Calculus/Science & Engineering (A)       20B  WI08     260
# 84  MATH 20B  - Calculus/Science & Engineering (B)       20B  WI08      58
# 85  MATH 20B  - Calculus/Science & Engineering (D)       20B  WI08     228
# 86  MATH 20B  - Calculus/Science & Engineering (A)       20B  FA07     192
# 87  MATH 20B  - Calculus/Science & Engineering (B)       20B  FA07     177
# 88  MATH 20B  - Calculus/Science & Engineering (C)       20B  FA07     121
# 89  MATH 20B  - Calculus/Science & Engineering (E)       20B  FA07     190
#
#     evalMade rcmndClass rcmndInstructor studyHrs avgGradeExpected  \
# 0        160     70.8 %          94.2 %     7.75        B- (2.76)
# 1         63     74.1 %          74.1 %     6.75        B- (2.88)
# 2         85     80.0 %          70.0 %     7.21         B (3.05)
# 3        165     71.6 %          53.5 %     7.49        B- (2.71)
# 4        110     88.2 %          68.6 %     7.21        B+ (3.37)
# 5        111     97.1 %          96.2 %     5.41        B+ (3.48)
# 6        155     75.5 %          14.6 %     7.17         B (3.13)
# 7         58     92.3 %          69.2 %     5.46        B+ (3.62)
# 8         25     87.5 %          45.8 %    10.59        B+ (3.38)
# 9         37     81.1 %          78.4 %     9.42         B (3.03)
# 10        84     75.3 %          58.4 %     7.11        B- (2.72)
# 11        73     86.3 %          84.9 %     5.35        B+ (3.32)
# 12       174     86.7 %          98.8 %     7.37        B- (2.85)
# 13       123     83.3 %          70.2 %     6.36         B (3.24)
# 14        95     85.6 %          80.0 %     5.91         B (3.15)
# 15        80     82.7 %          33.3 %     6.47         B (3.08)
# 16       138     81.1 %          34.8 %     7.46        C+ (2.62)
# 17       133     98.4 %         100.0 %     6.50        B+ (3.65)
# 18       164     86.4 %          93.2 %     6.69        B- (2.87)
# 19       112     84.5 %          63.6 %     5.95         B (3.10)
# 20       112     93.7 %          74.8 %     5.15        A- (3.71)
# 21        69     88.9 %          66.7 %     6.34         B (3.26)
# 22        96     92.2 %          60.0 %     6.72        B+ (3.30)
# 23       183     88.5 %          97.7 %     6.73        B- (2.94)
# 24        53     88.5 %          44.2 %     6.38         B (3.24)
# 25        87     97.3 %          72.0 %     6.18        B+ (3.53)
# 26       108     81.6 %          43.9 %     7.19         B (3.07)
# 27       134     96.1 %         100.0 %     6.50        B+ (3.40)
# 28       121     83.3 %          44.7 %     6.62         B (3.25)
# 29       107     94.1 %          81.4 %     6.30        B+ (3.56)
# ..       ...        ...             ...      ...              ...
# 60       108     86.9 %          59.4 %     6.05         B (3.22)
# 61       156     90.3 %          71.0 %     6.77         B (3.17)
# 62       164     86.6 %          35.4 %     5.80         B (3.26)
# 63       109     85.3 %          87.2 %     6.48        B+ (3.43)
# 64       119     86.6 %          34.5 %     5.60         B (3.29)
# 65       115     86.0 %          96.5 %     6.71         B (3.12)
# 66        85     87.1 %          71.8 %     6.45         B (3.10)
# 67        51     76.0 %          47.9 %     5.72        B- (2.91)
# 68       211     92.9 %         100.0 %     6.13         B (3.19)
# 69       169     95.8 %          91.6 %     4.86        B+ (3.43)
# 70       181     88.8 %          50.6 %     4.90         B (3.12)
# 71       121     88.1 %          34.7 %     4.74        B+ (3.60)
# 72        81     90.1 %          72.8 %     3.71        B+ (3.41)
# 73        41     70.0 %          82.5 %     5.27         B (3.06)
# 74        91     84.3 %          86.5 %     5.69         B (3.24)
# 75       188     90.9 %          85.5 %     4.93         B (3.30)
# 76       183     93.3 %          99.4 %     4.95         B (3.21)
# 77       150     97.2 %          95.2 %     5.12        B+ (3.49)
# 78       108     88.9 %          76.9 %     4.78         B (3.25)
# 79       134     79.1 %          51.9 %     4.76         B (3.14)
# 80       117     91.1 %          89.5 %     5.34         B (3.27)
# 81        77     76.6 %          53.2 %     5.59         B (3.15)
# 82       105     90.1 %         100.0 %     5.53         B (3.12)
# 83       125     83.6 %          95.9 %     5.44         B (3.02)
# 84        33     72.7 %          33.3 %     4.50        B- (2.97)
# 85       130     92.2 %          95.3 %     5.48         B (3.09)
# 86        92     92.3 %          98.9 %     6.02         B (3.15)
# 87       129     80.2 %          61.9 %     5.93        B- (2.85)
# 88        87     78.8 %          61.2 %     5.64        B- (2.91)
# 89       137     93.4 %          94.2 %     5.11        B+ (3.41)
#
#    avgGradeRecieved
# 0          C (2.21)
# 1         B- (2.79)
# 2         C+ (2.69)
# 3         C+ (2.56)
# 4         C+ (2.40)
# 5          B (3.19)
# 6         B- (2.75)
# 7         C+ (2.66)
# 8         B- (2.85)
# 9         B- (2.84)
# 10        C+ (2.63)
# 11        C+ (2.63)
# 12        C+ (2.33)
# 13         B (3.13)
# 14        C+ (2.36)
# 15        C+ (2.63)
# 16        C+ (2.66)
# 17         B (3.18)
# 18        C+ (2.47)
# 19        B- (2.83)
# 20         B (3.07)
# 21        C+ (2.66)
# 22        C+ (2.52)
# 23         C (2.23)
# 24        C+ (2.38)
# 25         B (3.05)
# 26        C+ (2.41)
# 27        B- (2.70)
# 28         B (3.22)
# 29         B (3.10)
# ..              ...
# 60        B- (2.77)
# 61        B- (2.84)
# 62        B- (2.83)
# 63        B- (2.87)
# 64        B- (2.71)
# 65        C+ (2.56)
# 66        C+ (2.56)
# 67        C+ (2.52)
# 68        C+ (2.56)
# 69        B- (2.83)
# 70        C+ (2.66)
# 71        B- (2.72)
# 72        B- (2.74)
# 73        C+ (2.54)
# 74        C+ (2.53)
# 75        B- (2.71)
# 76        C+ (2.58)
# 77        B- (2.80)
# 78        B- (2.79)
# 79        C+ (2.50)
# 80        C+ (2.53)
# 81        B- (2.80)
# 82        C+ (2.63)
# 83        C+ (2.39)
# 84        C+ (2.43)
# 85        B- (2.72)
# 86        C+ (2.43)
# 87        B- (2.71)
# 88        C+ (2.60)
# 89        C+ (2.62)
#
# [90 rows x 11 columns]
#                                    Name  \
# 0                 Longo, Brian Mitchell
# 1                       Bowers, Adam R.
# 2                    Gawlik, Evan Scott
# 3                 Tucker, Henry Jackson
# 4             Salehi Golsefidy, Alireza
# 5                         Tesler, Glenn
# 6                       Conant, James R
# 7              Barrese, Kenneth William
# 8                         Mohanty, Sara
# 9                 Eggers, John Dietrich
# 10             Barrese, Kenneth William
# 11                       Jiang, Zonglin
# 12                 Carter, Anne Toulson
# 13                        Mohanty, Sara
# 14                        Tesler, Glenn
# 15                             Wang, Xu
# 16                    Cheng, Hsiao-Bing
# 17                      Bowers, Adam R.
# 18                          Saab, Rayan
# 19                Eggers, John Dietrich
# 20                      Oliver, Jesus R
# 21            Banaszak, Grzegorz Marian
# 22                       Wang, Xingting
# 23                   Bucur, Alina Ioana
# 24                            Wang, Jie
# 25                      Bowers, Adam R.
# 26            Salehi Golsefidy, Alireza
# 27                       Wang, Xingting
# 28                        Chow, Bennett
# 29                        Tesler, Glenn
# ..                                  ...
# 69  Popescu, Cristian D.
# 70  Young, Stephen J.
# 71  Rogalski, Daniel
# 72  Popescu, Cristian D.
# 73  Zhang, Yuan
# 74  Shopple, John P.
# 75  Yoo, Meesue
# 76  Lin, James P.
# 77  De Winter, Stefaan
# 78  Sterbenz, Jacob
# 79  Szypowski, Ryan S.
# 80                           Agler, Jim
# 81               Fitzsimmons, Patrick J
# 82                      Chan, Ping-Shun
# 83                               Li, Bo
# 84  Kitchloo, Nitya
# 85  Horton, Matthew D.
# 86  Evans, Ronald J.
# 87  Ni, Lei
# 88       Eggers, John Dietrich
# 89       Cioaba, Sebastian
# 90       Bender, Edward A.
# 91       Cioaba, Sebastian
# 92       Chan, Ping-Shun
# 93       Gatzouras, Dimitrios
# 94       Evans, Ronald J.
# 95       Rabin, Jeffrey Mark
# 96       Nagy, Gabriel
# 97       Mengi, Emre
# 98       Cioaba, Sebastian
#
#                                             course courseNum  term  enroll  \
# 0    MATH 20C - Calculus&Analyt Geom/Sci&Engnr (A)       20C  WI17     154
# 1    MATH 20C - Calculus&Analyt Geom/Sci&Engnr (B)       20C  WI17     414
# 2    MATH 20C - Calculus&Analyt Geom/Sci&Engnr (C)       20C  WI17     391
# 3    MATH 20C - Calculus&Analyt Geom/Sci&Engnr (A)       20C  FA16     182
# 4    MATH 20C - Calculus&Analyt Geom/Sci&Engnr (B)       20C  FA16     336
# 5    MATH 20C - Calculus&Analyt Geom/Sci&Engnr (C)       20C  FA16     330
# 6    MATH 20C - Calculus&Analyt Geom/Sci&Engnr (D)       20C  FA16     376
# 7    MATH 20C - Calculus&Analyt Geom/Sci&Engnr (E)       20C  FA16     281
# 8    MATH 20C - Calculus&Analyt Geom/Sci&Engnr (A)       20C  WI16     161
# 9    MATH 20C - Calculus&Analyt Geom/Sci&Engnr (B)       20C  WI16     421
# 10   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (C)       20C  WI16     315
# 11   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (D)       20C  WI16     239
# 12   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (A)       20C  FA15     368
# 13   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (B)       20C  FA15     371
# 14   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (C)       20C  FA15     372
# 15   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (E)       20C  FA15     268
# 16   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (F)       20C  FA15     187
# 17   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (B)       20C  SP15     293
# 18   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (C)       20C  SP15     152
# 19   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (A)       20C  WI15     369
# 20   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (B)       20C  WI15     271
# 21   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (C)       20C  WI15     202
# 22   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (D)       20C  WI15     303
# 23   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (A)       20C  FA14     309
# 24   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (B)       20C  FA14     397
# 25   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (C)       20C  FA14     413
# 26   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (D)       20C  FA14     420
# 27   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (E)       20C  FA14     323
# 28   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (A)       20C  WI14     212
# 29   MATH 20C - Calculus&Analyt Geom/Sci&Engnr (B)       20C  WI14     398
# ..                                             ...       ...   ...     ...
# 69  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (A)       20C  SP10     159
# 70  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (B)       20C  SP10     186
# 71  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (C)       20C  SP10     295
# 72  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (A)       20C  WI10     205
# 73  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (C)       20C  WI10     208
# 74  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (D)       20C  WI10     235
# 75  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (A)       20C  FA09     159
# 76  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (B)       20C  FA09     282
# 77  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (C)       20C  FA09     271
# 78  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (D)       20C  FA09     168
# 79  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (C)       20C  SP09     281
# 80  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (A)       20C  WI09     176
# 81  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (B)       20C  WI09     300
# 82  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (C)       20C  WI09     193
# 83  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (D)       20C  WI09     209
# 84  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (A)       20C  FA08     272
# 85  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (B)       20C  FA08     274
# 86  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (C)       20C  FA08     260
# 87  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (D)       20C  FA08     137
# 88  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (B)       20C  SP08     181
# 89  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (C)       20C  SP08      99
# 90  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (A)       20C  WI08     108
# 91  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (B)       20C  WI08     207
# 92  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (C)       20C  WI08     195
# 93  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (D)       20C  WI08     172
# 94  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (E)       20C  WI08     170
# 95  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (A)       20C  FA07     273
# 96  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (B)       20C  FA07     257
# 97  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (C)       20C  FA07     167
# 98  MATH 20C  - Calculus&Analyt Geom/Sci&Engnr (D)       20C  FA07     311
#
#     evalMade rcmndClass rcmndInstructor studyHrs avgGradeExpected  \
# 0         80     94.7 %         100.0 %     5.82        B+ (3.32)
# 1        190     89.8 %          91.5 %     6.85         B (3.25)
# 2        203     93.5 %          97.0 %     6.12        B+ (3.34)
# 3        125     66.9 %           8.5 %     8.34        B- (2.89)
# 4        253     90.9 %          94.2 %     7.14        B+ (3.45)
# 5        161     89.9 %          65.5 %     6.71         B (3.24)
# 6        207     95.4 %          97.0 %     5.33        A- (3.71)
# 7        132     88.7 %          61.3 %     6.58         B (3.20)
# 8         90     85.4 %          62.9 %     6.16         B (3.06)
# 9        229     90.4 %          90.8 %     6.54         B (3.27)
# 10       149     88.1 %          76.2 %     5.83        B+ (3.38)
# 11       125     78.7 %          32.0 %     6.10         B (3.28)
# 12       233     97.8 %          96.9 %     5.78        B+ (3.64)
# 13       181     93.8 %          77.0 %     6.50        B+ (3.40)
# 14       158     82.1 %          74.8 %     7.81         B (3.19)
# 15       158     85.1 %          46.8 %     6.80        B+ (3.68)
# 16        90     92.1 %          71.9 %     6.43        B+ (3.33)
# 17       135     94.7 %          98.5 %     6.01        B+ (3.31)
# 18        84     91.4 %          92.6 %     5.64         B (3.28)
# 19       185     91.2 %          91.7 %     6.16         B (3.28)
# 20       134     96.1 %          96.1 %     6.52        B+ (3.44)
# 21       101     86.3 %          61.1 %     4.65        B+ (3.44)
# 22       167     93.2 %          92.6 %     5.34        A- (3.79)
# 23       180     85.9 %          45.9 %     6.42        B+ (3.32)
# 24       246     93.6 %          72.8 %     5.32        B+ (3.69)
# 25       321     94.4 %          98.0 %     7.40        B+ (3.46)
# 26       391     91.2 %          95.1 %     5.73        B+ (3.52)
# 27       209     94.1 %          86.2 %     4.92        A- (3.80)
# 28       116     90.4 %          94.7 %     5.22        B+ (3.48)
# 29       200     90.6 %          88.5 %     6.25        B+ (3.35)
# ..       ...        ...             ...      ...              ...
# 69        65     85.9 %          74.2 %     6.50         B (3.15)
# 70        84     73.8 %          38.3 %     7.46        B- (2.76)
# 71       147     84.2 %          76.7 %     6.60         B (3.18)
# 72       101     83.0 %          78.8 %     6.32         B (3.05)
# 73       105     84.8 %          50.5 %     4.79         B (3.20)
# 74       107     92.5 %          83.2 %     5.43         B (3.30)
# 75       128     89.7 %          48.4 %     4.84        B+ (3.39)
# 76       129     96.9 %          90.6 %     6.00        B+ (3.54)
# 77       185     95.1 %          96.2 %     5.04        B+ (3.63)
# 78       114     90.4 %          88.6 %     5.22        B+ (3.38)
# 79       162     90.1 %          96.9 %     5.03        B+ (3.39)
# 80        89     90.8 %          70.5 %     5.05         B (3.30)
# 81       230     91.4 %          95.0 %     4.44        B+ (3.43)
# 82       111     91.0 %          96.4 %     3.58        B+ (3.39)
# 83       109     82.1 %          51.0 %     5.09        B- (2.97)
# 84       176     93.8 %          98.3 %     4.93        B+ (3.46)
# 85       154     93.4 %          98.0 %     5.60        B+ (3.32)
# 86       159     84.2 %          91.5 %     5.14        B+ (3.35)
# 87        78     86.8 %          65.8 %     4.63        B+ (3.30)
# 88       106     81.7 %          94.2 %     5.18         B (3.22)
# 89        45     88.9 %          91.1 %     5.30         B (3.23)
# 90        56     70.9 %          38.2 %     4.50         B (3.09)
# 91       119     81.9 %          93.1 %     5.21         B (3.03)
# 92        85     84.5 %          74.7 %     4.36         B (3.16)
# 93        96     78.5 %          69.9 %     4.94         B (3.29)
# 94        98     88.5 %          86.2 %     4.34         B (3.19)
# 95       193     87.4 %          96.7 %     5.02         B (3.13)
# 96       150     93.9 %          92.6 %     4.57        B+ (3.51)
# 97        75     77.3 %          56.0 %     5.32         B (3.12)
# 98       156     96.0 %          94.6 %     5.48        B+ (3.48)
#
#    avgGradeRecieved
# 0         B- (2.77)
# 1         B- (2.76)
# 2         B- (2.76)
# 3         B- (2.80)
# 4         B- (2.77)
# 5         B- (2.73)
# 6          B (3.24)
# 7         B- (2.71)
# 8         C+ (2.32)
# 9         C+ (2.60)
# 10        C+ (2.63)
# 11        B- (2.70)
# 12        B- (2.95)
# 13        B- (2.71)
# 14        C+ (2.63)
# 15        C+ (2.68)
# 16        B- (2.88)
# 17        C+ (2.58)
# 18        C+ (2.63)
# 19        B- (2.90)
# 20        B- (2.92)
# 21         B (3.13)
# 22        B+ (3.67)
# 23        C+ (2.54)
# 24         B (3.26)
# 25        B+ (3.40)
# 26        B- (2.85)
# 27        B+ (3.52)
# 28        B- (2.93)
# 29        C+ (2.62)
# ..              ...
# 69        C+ (2.52)
# 70        C+ (2.68)
# 71        B- (2.76)
# 72        B- (2.82)
# 73        B- (2.75)
# 74        C+ (2.69)
# 75        B- (2.85)
# 76        B- (2.82)
# 77        B- (2.74)
# 78        B- (2.77)
# 79        C+ (2.66)
# 80         B (3.01)
# 81        B- (2.96)
# 82        B- (2.77)
# 83        C+ (2.62)
# 84        B- (2.79)
# 85        B- (2.82)
# 86        C+ (2.70)
# 87        C+ (2.32)
# 88        C+ (2.39)
# 89        C+ (2.64)
# 90        C+ (2.62)
# 91        B- (2.73)
# 92        B- (2.90)
# 93        C+ (2.70)
# 94        B- (2.89)
# 95        C+ (2.54)
# 96        B- (2.79)
# 97        B- (2.80)
# 98        C+ (2.45)
#
# [99 rows x 11 columns]
#                                    Name  \
# 0                         Behzadan, Ali
# 1                  Merkurjev, Ekaterina
# 2                     Cheng, Hsiao-Bing
# 3                         Mohanty, Sara
# 4            Deotte, Christopher George
# 5                          Lu, Shaoying
# 6            Oswald, Albert Georg Peter
# 7               Wong, Elizabeth Lai Sum
# 8                             Wang, Jie
# 9                            Peng, Xing
# 10                    Sorensen, Claus M
# 11            Banaszak, Grzegorz Marian
# 12                         Lu, Shaoying
# 13                      Driver, Bruce K
# 14                        Ioana, Adrian
# 15             Schillewaert, Jeroen Jan
# 16                           Peng, Xing
# 17                         Nie, Jiawang
# 18                Stevens, Laura Jeanne
# 19  Saxena, Rishu
# 20  Lou, Yifei
# 21  Saxena, Rishu
# 22  Minor, Andre J
# 23  Ohsawa, Tomoki
# 24  Harel, Guershon
# 25  Mirjalalieh Shirazi, Mir Hamed
# 26  Keilberg, Marc Daniel
# 27  Stern, Ari
# 28  Driver, Bruce K
# 29  Vankerschaver, Joris G
# 30  Stevens, Laura Jeanne
# 31  Kong, Shengli
# 32  Lin, James P.
# 33  Gan, Wee T.
# 34  Shopple, John P.
# 35  Shingel, Tatiana
# 36  Chan, Ping-Shun
# 37                               Li, Bo
# 38                     Evans, Ronald J.
# 39  Szypowski, Ryan S.
# 40       Li, Bo
# 41       Linshaw, Andrew Ross
# 42       Lunasin, Evelyn Manalo
# 43       Nagy, Gabriel
# 44       Mengi, Emre
# 45       Lin, James P.
# 46       Harel, Guershon
#
#                                             course courseNum  term  enroll  \
# 0                    MATH 20F - Linear Algebra (A)       20F  SP16     315
# 1                    MATH 20F - Linear Algebra (A)       20F  WI16     328
# 2                    MATH 20F - Linear Algebra (B)       20F  WI16     186
# 3                    MATH 20F - Linear Algebra (C)       20F  WI16     195
# 4                    MATH 20F - Linear Algebra (D)       20F  WI16     337
# 5                    MATH 20F - Linear Algebra (A)       20F  FA15     289
# 6                    MATH 20F - Linear Algebra (B)       20F  FA15     231
# 7                    MATH 20F - Linear Algebra (C)       20F  FA15     244
# 8                    MATH 20F - Linear Algebra (A)       20F  SP15     361
# 9                    MATH 20F - Linear Algebra (A)       20F  WI15     343
# 10                   MATH 20F - Linear Algebra (C)       20F  WI15     303
# 11                   MATH 20F - Linear Algebra (C)       20F  FA14     188
# 12                   MATH 20F - Linear Algebra (A)       20F  FA13     199
# 13                   MATH 20F - Linear Algebra (B)       20F  FA13     287
# 14                   MATH 20F - Linear Algebra (A)       20F  SP13     212
# 15                   MATH 20F - Linear Algebra (A)       20F  WI13     288
# 16                   MATH 20F - Linear Algebra (B)       20F  WI13     139
# 17                   MATH 20F - Linear Algebra (C)       20F  WI13     263
# 18                   MATH 20F - Linear Algebra (A)       20F  FA12     334
# 19  MATH 20F  - Linear Algebra                 (B)       20F  SP12     315
# 20  MATH 20F  - Linear Algebra                 (A)       20F  WI12     199
# 21  MATH 20F  - Linear Algebra                 (B)       20F  WI12     192
# 22  MATH 20F  - Linear Algebra                 (C)       20F  WI12     245
# 23  MATH 20F  - Linear Algebra                 (A)       20F  FA11     325
# 24  MATH 20F  - Linear Algebra                 (B)       20F  FA11     207
# 25  MATH 20F  - Linear Algebra                 (A)       20F  WI11     195
# 26  MATH 20F  - Linear Algebra                 (B)       20F  WI11     199
# 27  MATH 20F  - Linear Algebra                 (C)       20F  WI11     215
# 28  MATH 20F  - Linear Algebra                 (A)       20F  FA10     183
# 29  MATH 20F  - Linear Algebra                 (B)       20F  FA10     296
# 30  MATH 20F  - Linear Algebra                 (A)       20F  SP10     202
# 31  MATH 20F  - Linear Algebra                 (B)       20F  SP10     316
# 32  MATH 20F  - Linear Algebra                 (A)       20F  WI10     124
# 33  MATH 20F  - Linear Algebra                 (B)       20F  WI10     190
# 34  MATH 20F  - Linear Algebra                 (C)       20F  WI10     206
# 35  MATH 20F  - Linear Algebra                 (A)       20F  FA09     186
# 36  MATH 20F  - Linear Algebra                 (B)       20F  SP09     289
# 37  MATH 20F  - Linear Algebra                 (B)       20F  WI09     155
# 38  MATH 20F  - Linear Algebra                 (C)       20F  WI09     187
# 39  MATH 20F  - Linear Algebra                 (A)       20F  FA08     138
# 40  MATH 20F  - Linear Algebra                 (B)       20F  SP08     163
# 41  MATH 20F  - Linear Algebra                 (C)       20F  SP08     149
# 42  MATH 20F  - Linear Algebra                 (A)       20F  WI08     169
# 43  MATH 20F  - Linear Algebra                 (B)       20F  WI08     190
# 44  MATH 20F  - Linear Algebra                 (C)       20F  WI08     128
# 45  MATH 20F  - Linear Algebra                 (A)       20F  FA07     178
# 46  MATH 20F  - Linear Algebra                 (B)       20F  FA07     105
#
#     evalMade rcmndClass rcmndInstructor studyHrs avgGradeExpected  \
# 0        131     93.0 %          96.1 %     5.89        A- (3.84)
# 1        187     84.3 %          46.1 %     6.28        B+ (3.37)
# 2        100     86.2 %          72.3 %     6.81        B+ (3.39)
# 3        103     75.8 %          42.4 %     5.94         B (3.10)
# 4        173     95.8 %          96.4 %     5.83        B+ (3.65)
# 5        124     86.6 %          58.0 %     6.04        B+ (3.43)
# 6        100     70.5 %          40.0 %     6.81         B (3.15)
# 7         98     97.9 %          96.8 %     6.19        A- (3.75)
# 8        165     89.2 %          75.9 %     5.49        B+ (3.49)
# 9        242     87.9 %          59.2 %     6.15        B+ (3.51)
# 10       153     89.2 %          63.5 %     6.09         B (3.28)
# 11        78     69.9 %          23.3 %     6.47         B (3.10)
# 12        84     81.3 %          22.5 %     6.10        B+ (3.41)
# 13       122     94.1 %          90.7 %     5.50        B+ (3.66)
# 14        86     91.8 %          97.6 %     5.27        B+ (3.61)
# 15       125     82.1 %          62.6 %     6.33         B (3.18)
# 16       100     90.7 %          58.8 %     5.24        B+ (3.33)
# 17       113     90.1 %          91.0 %     6.08        A- (3.74)
# 18       151     86.6 %          89.4 %     6.32        B+ (3.48)
# 19       142     81.6 %          34.0 %     6.37         B (3.29)
# 20        99     87.8 %          32.3 %     6.96         B (3.27)
# 21        90     86.5 %          42.7 %     5.47        B+ (3.38)
# 22       111     90.1 %          91.0 %     7.00        B+ (3.64)
# 23       164     95.7 %          96.3 %     5.35        B+ (3.46)
# 24        90     86.5 %          82.0 %     7.12        B+ (3.48)
# 25        97     81.4 %          65.6 %     5.88         B (3.23)
# 26       107     77.1 %          32.7 %     5.00         B (3.27)
# 27       128     80.3 %          74.8 %     5.63         B (3.27)
# 28        89     94.4 %          92.0 %     6.14        B+ (3.43)
# 29       162     85.7 %          84.4 %     5.86         B (3.26)
# 30        97     88.4 %          98.9 %     5.69        B+ (3.40)
# 31       142     89.9 %          59.0 %     5.19        B+ (3.43)
# 32        57     83.6 %          61.8 %     6.54        B+ (3.43)
# 33        78     82.1 %          64.1 %     5.60         B (3.16)
# 34        84     91.5 %          71.6 %     5.51        B+ (3.48)
# 35        92     79.1 %          55.6 %     4.79        B+ (3.41)
# 36       150     88.3 %          93.8 %     3.96        B+ (3.45)
# 37        81     92.2 %          84.4 %     5.19        B+ (3.44)
# 38       111     83.5 %          89.0 %     4.82        B+ (3.39)
# 39        64     87.1 %          93.5 %     4.89        B+ (3.49)
# 40        89     89.9 %          87.6 %     4.25        B+ (3.46)
# 41        71     91.2 %          75.0 %     4.19        B+ (3.32)
# 42        97     85.4 %          89.6 %     4.40         B (3.27)
# 43        80     91.3 %          91.3 %     4.63        B+ (3.50)
# 44        52     76.5 %          70.6 %     5.96         B (3.25)
# 45        75     83.6 %          78.1 %     6.34        B+ (3.41)
# 46        77     94.8 %          88.3 %     4.66        B+ (3.50)
#
#    avgGradeRecieved
# 0          B (3.15)
# 1         B- (2.99)
# 2         B- (2.78)
# 3          C (2.01)
# 4          B (3.07)
# 5          B (3.15)
# 6         B- (2.79)
# 7          B (3.18)
# 8         B- (2.99)
# 9         B- (2.72)
# 10        B- (2.90)
# 11        B- (2.76)
# 12         B (3.08)
# 13         B (3.06)
# 14        C+ (2.59)
# 15        C+ (2.59)
# 16        B- (2.71)
# 17         B (3.20)
# 18        B- (2.75)
# 19        B- (2.90)
# 20        B- (2.73)
# 21        B- (2.99)
# 22        B- (2.93)
# 23         B (3.02)
# 24        C+ (2.68)
# 25        C+ (2.67)
# 26        C+ (2.68)
# 27        C+ (2.59)
# 28        B- (2.75)
# 29        B- (2.81)
# 30        C+ (2.62)
# 31        B- (2.85)
# 32        B- (2.77)
# 33        B- (2.81)
# 34        C+ (2.69)
# 35        C+ (2.66)
# 36        B- (2.74)
# 37        C+ (2.63)
# ...
# 60  COGS 107A  - Neuroanatomy and Physiology    (A)      107A  FA07     150
#
#     evalMade rcmndClass rcmndInstructor studyHrs avgGradeExpected  \
# 0        173     85.5 %          57.2 %     5.07         B (3.12)
# 1         39     97.3 %         100.0 %     5.47        B+ (3.67)
# 2        155     94.7 %          99.3 %     4.24        B+ (3.59)
# 3        243     93.8 %          95.6 %     2.91        B+ (3.65)
# 4        234     97.4 %          99.6 %     5.40        B+ (3.38)
# 5        160     83.0 %          58.8 %     9.49         B (3.09)
# 6        154     84.1 %          92.7 %     4.02        B+ (3.35)
# 7        142     95.5 %          99.2 %     4.03        B+ (3.65)
# 8        147     79.7 %          60.9 %     5.22        B- (2.85)
# 9        120     79.7 %          91.5 %     3.54        B+ (3.35)
# 10       164     91.3 %          97.3 %     2.86        B+ (3.66)
# 11       174     97.0 %          99.4 %     4.64        B+ (3.52)
# 12       125     78.0 %          81.3 %     5.28        B+ (3.34)
# 13       139     92.6 %          89.0 %     5.55        B+ (3.42)
# 14        85     91.1 %          97.5 %     3.96        B+ (3.49)
# 15        15     66.7 %         100.0 %     5.83         B (3.07)
# 16       136     90.8 %          99.2 %     3.21        B+ (3.59)
# 17       108     94.3 %          99.0 %     4.34        B+ (3.68)
# 18       101     74.7 %          80.0 %     4.03         B (3.18)
# 19        63     83.1 %          78.0 %     3.43        B+ (3.50)
# 20       137     88.4 %          82.6 %     5.09        B+ (3.59)
# 21       119     94.2 %          99.0 %     5.03        B+ (3.54)
# 22        69     85.2 %          93.4 %     5.57        B+ (3.43)
# 23        66     96.9 %         100.0 %     4.44        B+ (3.44)
# 24       204     71.8 %          77.9 %     4.85         B (3.28)
# 25        95     96.8 %          97.8 %     4.63        B+ (3.47)
# 26        73     53.8 %          76.9 %     5.16        B+ (3.31)
# 27        89     89.0 %          85.4 %     6.16         B (3.01)
# 28        51     85.4 %          95.8 %     4.41        B+ (3.34)
# 29        15     93.3 %         100.0 %     6.23        B+ (3.53)
# ..       ...        ...             ...      ...              ...
# 31        47     66.0 %          87.2 %     4.02         B (3.07)
# 32       150     87.0 %          93.1 %     3.65        B+ (3.69)
# 33       146     97.7 %          97.7 %     5.01        B+ (3.50)
# 34        90     92.0 %          97.7 %     4.27        B+ (3.62)
# 35       125     73.6 %          82.4 %     4.00         B (3.14)
# 36       153     81.6 %          87.6 %     5.25         B (3.18)
# 37        97     94.8 %          95.9 %     5.20        B+ (3.45)
# 38        95     54.8 %          62.4 %     5.62        B+ (3.38)
# 39       101     94.1 %          94.1 %     6.80         B (3.29)
# 40       123     82.0 %          87.7 %     3.62        B+ (3.56)
# 41       129     86.8 %          91.4 %     4.02        B+ (3.52)
# 42       126     92.0 %          96.0 %     3.56        B+ (3.50)
# 43       102     90.2 %          94.1 %     5.34        B+ (3.43)
# 44       116     62.9 %          81.9 %     5.60         B (3.25)
# 45       164     90.2 %          90.1 %     6.76         B (3.10)
# 46       106     85.6 %          84.2 %     3.64        B+ (3.39)
# 47       143     84.6 %          79.6 %     3.33        B+ (3.62)
# 48       118     93.2 %          92.3 %     4.19        B+ (3.44)
# 49        78     68.8 %          87.0 %     5.03        B+ (3.46)
# 50       112     90.9 %          89.3 %     5.40         B (3.16)
# 51        93     64.5 %          78.5 %     3.19         B (3.14)
# 52        98     95.8 %          90.6 %     4.85        B+ (3.41)
# 53       149     89.7 %          87.0 %     2.51         B (3.27)
# 54        91     49.4 %          51.1 %     4.39        B+ (3.55)
# 55       142     93.4 %          95.6 %     6.21        B+ (3.31)
# 56        75     62.7 %          57.5 %     3.33         B (3.21)
# 57       110     90.9 %          98.2 %     3.30        B+ (3.34)
# 58        70     95.6 %          79.1 %     4.73        B+ (3.32)
# 59        88     75.9 %          95.2 %     4.57        B+ (3.38)
# 60        91     92.0 %          95.5 %     5.26         B (3.28)
#
#    avgGradeRecieved
# 0          B (3.11)
# 1          B (3.24)
# 2         B+ (3.31)
# 3         B+ (3.33)
# 4          B (3.04)
# 5          B (3.19)
# 6          B (3.05)
# 7         B+ (3.33)
# 8         B- (2.74)
# 9          B (3.03)
# 10        B+ (3.53)
# 11         B (3.22)
# 12        B+ (3.55)
# 13        B- (2.99)
# 14         B (3.21)
# 15        B+ (3.34)
# 16         B (3.25)
# 17         B (3.22)
# 18        C+ (2.64)
# 19         B (3.12)
# 20        B+ (3.62)
# 21         B (3.16)
# 22        B+ (3.33)
# 23         B (3.01)
# 24        B- (2.80)
# 25         B (3.05)
# 26         B (3.25)
# 27        B- (2.91)
# 28         B (3.04)
# 29        B+ (3.39)
# ..              ...
# 31        C+ (2.69)
# 32         B (3.20)
# 33         B (3.15)
# 34        B+ (3.33)
# 35        B- (2.77)
# 36        B- (2.80)
# 37         B (3.05)
# 38         B (3.14)
# 39        B- (2.95)
# 40         B (3.28)
# 41         B (3.05)
# 42        B- (2.91)
# 43         B (3.02)
# 44         B (3.11)
# 45        B- (2.79)
# 46        B- (2.95)
# 47         B (3.11)
# 48        B- (2.88)
# 49         B (3.21)
# 50        B- (2.83)
# 51        B- (2.95)
# 52        B- (2.83)
# 53        B- (2.86)
# 54        B+ (3.33)
# 55        B- (2.86)
# 56         B (3.12)
# 57        C+ (2.52)
# 58        C+ (2.68)
# 59         B (3.08)
# 60        B- (2.82)
#
# [61 rows x 11 columns]
#                     Name                                     course courseNum  \
# 0  Barrera, Steven James  COGS 14A - Intro. to Research Methods (A)       14A
# 1      Rossano, Federico  COGS 14A - Intro. to Research Methods (A)       14A
# 2      Rossano, Federico  COGS 14A - Intro. to Research Methods (A)       14A
# 3  Barrera, Steven James  COGS 14A - Intro. to Research Methods (A)       14A
# 4       Marghetis, Tyler  COGS 14A - Intro. to Research Methods (A)       14A
# 5  Barrera, Steven James  COGS 14A - Intro. to Research Methods (A)       14A
# 6           Creel, Sarah  COGS 14A - Intro. to Research Methods (A)       14A
# 7  Barrera, Steven James  COGS 14A - Intro. to Research Methods (A)       14A
# 8        Nunez, Rafael E  COGS 14A - Intro. to Research Methods (A)       14A
# 9     Davenport, Tristan  COGS 14A - Intro. to Research Methods (A)       14A
#
#    term  enroll  evalMade rcmndClass rcmndInstructor studyHrs  \
# 0  WI17     276       155     94.7 %          99.3 %     4.24
# 1  FA16     196       154     84.1 %          92.7 %     4.02
# 2  WI16     166       120     79.7 %          91.5 %     3.54
# 3  FA15     149        85     91.1 %          97.5 %     3.96
# 4  S115      36        15     66.7 %         100.0 %     5.83
# 5  SP15     176       108     94.3 %          99.0 %     4.34
# 6  WI15     138        63     83.1 %          78.0 %     3.43
# 7  SP14     118        66     96.9 %         100.0 %     4.44
# 8  FA13     113        51     85.4 %          95.8 %     4.41
# 9  WI13     112        47     66.0 %          87.2 %     4.02
#
#   avgGradeExpected avgGradeRecieved
# 0        B+ (3.59)        B+ (3.31)
# 1        B+ (3.35)         B (3.05)
# 2        B+ (3.35)         B (3.03)
# 3        B+ (3.49)         B (3.21)
# 4         B (3.07)        B+ (3.34)
# 5        B+ (3.68)         B (3.22)
# 6        B+ (3.50)         B (3.12)
# 7        B+ (3.44)         B (3.01)
# 8        B+ (3.34)         B (3.04)
# 9         B (3.07)        C+ (2.69)
#                                    Name  \
# 0                   Walker, Esther Jane
# 1                 Barrera, Steven James
# 2                 Barrera, Steven James
# 3                 Barrera, Steven James
# 4                 Barrera, Steven James
# 5                 Barrera, Steven James
# 6                 Barrera, Steven James
# 7   Johnson, Christine M.
# 8   Johnson, Christine M.
# 9   Johnson, Christine M.
# 10                 Groppe, David Martin
# 11       Groppe, David Martin
#
#                                              course courseNum  term  enroll  \
# 0          COGS 101A - Sensation and Perception (A)      101A  WI17      90
# 1          COGS 101A - Sensation and Perception (A)      101A  FA16     410
# 2          COGS 101A - Sensation and Perception (A)      101A  FA15     304
# 3          COGS 101A - Sensation and Perception (A)      101A  FA14     254
# 4          COGS 101A - Sensation and Perception (A)      101A  FA13     214
# 5          COGS 101A - Sensation and Perception (A)      101A  S213      28
# 6          COGS 101A - Sensation and Perception (A)      101A  FA12     296
# 7   COGS 101A  - Sensation and Perception       (A)      101A  FA11     223
# 8   COGS 101A  - Sensation and Perception       (A)      101A  FA10     165
# 9   COGS 101A  - Sensation and Perception       (A)      101A  FA09     157
# 10  COGS 101A  - Sensation and Perception       (A)      101A  WI09     187
# 11  COGS 101A  - Sensation and Perception       (A)      101A  FA07     117
#
#     evalMade rcmndClass rcmndInstructor studyHrs avgGradeExpected  \
# 0         39     97.3 %         100.0 %     5.47        B+ (3.67)
# 1        234     97.4 %          99.6 %     5.40        B+ (3.38)
# 2        174     97.0 %          99.4 %     4.64        B+ (3.52)
# 3        119     94.2 %          99.0 %     5.03        B+ (3.54)
# 4         95     96.8 %          97.8 %     4.63        B+ (3.47)
# 5         15     93.3 %         100.0 %     6.23        B+ (3.53)
# 6        146     97.7 %          97.7 %     5.01        B+ (3.50)
# 7         97     94.8 %          95.9 %     5.20        B+ (3.45)
# 8        102     90.2 %          94.1 %     5.34        B+ (3.43)
# 9        118     93.2 %          92.3 %     4.19        B+ (3.44)
# 10        98     95.8 %          90.6 %     4.85        B+ (3.41)
# 11        70     95.6 %          79.1 %     4.73        B+ (3.32)
#
#    avgGradeRecieved
# 0          B (3.24)
# 1          B (3.04)
# 2          B (3.22)
# 3          B (3.16)
# 4          B (3.05)
# 5         B+ (3.39)
# 6          B (3.15)
# 7          B (3.05)
# 8          B (3.02)
# 9         B- (2.88)
# 10        B- (2.83)
# 11        C+ (2.68)
#                                   Name  \
# 0                  Renner, Nancy Owens
# 1                     Marghetis, Tyler
# 2                  Hutchins, Edwin Lee
# 3  Hutchins, Edwin Lee
# 4  Hutchins, Edwin Lee
# 5  Hutchins, Edwin Lee
# 6  Forster, Deborah
# 7       Hutchins, Edwin Lee
#
#                                             course courseNum  term  enroll  \
# 0            COGS 102A - Distributed Cognition (A)      102A  FA15     201
# 1            COGS 102A - Distributed Cognition (A)      102A  FA14     167
# 2            COGS 102A - Distributed Cognition (A)      102A  FA13     170
# 3  COGS 102A  - Distributed Cognition          (A)      102A  FA11     214
# 4  COGS 102A  - Distributed Cognition          (A)      102A  FA10     177
# 5  COGS 102A  - Distributed Cognition          (A)      102A  FA09     154
# 6  COGS 102A  - Distributed Cognition          (A)      102A  FA08     140
# 7  COGS 102A  - Distributed Cognition          (A)      102A  FA07     148
#
#    evalMade rcmndClass rcmndInstructor studyHrs avgGradeExpected  \
# 0       125     78.0 %          81.3 %     5.28        B+ (3.34)
# 1        69     85.2 %          93.4 %     5.57        B+ (3.43)
# 2        73     53.8 %          76.9 %     5.16        B+ (3.31)
# 3        95     54.8 %          62.4 %     5.62        B+ (3.38)
# 4       116     62.9 %          81.9 %     5.60         B (3.25)
# 5        78     68.8 %          87.0 %     5.03        B+ (3.46)
# 6        91     49.4 %          51.1 %     4.39        B+ (3.55)
# 7        88     75.9 %          95.2 %     4.57        B+ (3.38)
#
#   avgGradeRecieved
# 0        B+ (3.55)
# 1        B+ (3.33)
# 2         B (3.25)
# 3         B (3.14)
# 4         B (3.11)
# 5         B (3.21)
# 6        B+ (3.33)
# 7         B (3.08)
#                                   Name  \
# 0                    Boyle, Mary E. T.
# 1                      Pineda, Jaime A
# 2                      Pineda, Jaime A
# 3  Pineda, Jaime A
# 4  Pineda, Jaime A
# 5  Pineda, Jaime A
# 6  Pineda, Jaime A
# 7       Pineda, Jaime A
#
#                                             course courseNum  term  enroll  \
# 0      COGS 107A - Neuroanatomy and Physiology (B)      107A  FA16     304
# 1      COGS 107A - Neuroanatomy and Physiology (A)      107A  FA15     217
# 2      COGS 107A - Neuroanatomy and Physiology (A)      107A  FA13     206
# 3  COGS 107A  - Neuroanatomy and Physiology    (A)      107A  FA11     233
# 4  COGS 107A  - Neuroanatomy and Physiology    (A)      107A  FA10     206
# 5  COGS 107A  - Neuroanatomy and Physiology    (A)      107A  FA09     168
# 6  COGS 107A  - Neuroanatomy and Physiology    (A)      107A  FA08     187
# 7  COGS 107A  - Neuroanatomy and Physiology    (A)      107A  FA07     150
#
#    evalMade rcmndClass rcmndInstructor studyHrs avgGradeExpected  \
# 0       160     83.0 %          58.8 %     9.49         B (3.09)
# 1       139     92.6 %          89.0 %     5.55        B+ (3.42)
# 2        89     89.0 %          85.4 %     6.16         B (3.01)
# 3       101     94.1 %          94.1 %     6.80         B (3.29)
# 4       164     90.2 %          90.1 %     6.76         B (3.10)
# 5       112     90.9 %          89.3 %     5.40         B (3.16)
# 6       142     93.4 %          95.6 %     6.21        B+ (3.31)
# 7        91     92.0 %          95.5 %     5.26         B (3.28)
#
#   avgGradeRecieved
# 0         B (3.19)
# 1        B- (2.99)
# 2        B- (2.91)
# 3        B- (2.95)
# 4        B- (2.79)
# 5        B- (2.83)
# 6        B- (2.86)
# 7        B- (2.82)
#                                   Name  \
# 0                        Marx, Susan S
# 1                         Gupta, Anjum
# 2                        Marx, Susan S
# 3                        Marx, Susan S
# 4                        Marx, Susan S
# 5                  Lee, Cynthia Bailey
# 6  Lee, Cynthia Bailey
#
#                                          course courseNum  term  enroll  \
# 0          CSE 7 - Intro Programming MATLAB (A)         7  WI17     130
# 1          CSE 7 - Intro Programming MATLAB (A)         7  S216      45
# 2          CSE 7 - Intro Programming MATLAB (A)         7  SP16     133
# 3          CSE 7 - Intro Programming MATLAB (A)         7  WI16     130
# 4          CSE 7 - Intro Programming MATLAB (A)         7  WI14     100
# 5          CSE 7 - Intro Programming MATLAB (A)         7  WI13     138
# 6  CSE 7   - Intro Programming MATLAB       (A)         7  WI12     100
#
#    evalMade rcmndClass rcmndInstructor studyHrs avgGradeExpected  \
# 0        55     83.0 %          73.6 %     3.65        B+ (3.42)
# 1        27     88.0 %          88.0 %     7.92        A- (3.76)
# 2        57     84.6 %          76.9 %     4.85        B+ (3.51)
# 3        62     84.7 %          67.8 %     4.03        B+ (3.44)
# 4        41     76.3 %          63.2 %     3.66        B+ (3.43)
# 5        61     86.9 %          96.7 %     5.61        A- (3.77)
# 6        64     87.5 %          92.2 %     6.34        B+ (3.34)
#
#   avgGradeRecieved
# 0         B (3.24)
# 1        B+ (3.47)
# 2         B (3.22)
# 3         B (3.21)
# 4        B+ (3.50)
# 5        B+ (3.38)
# 6        B- (2.95)

# %%
len(cogsMajor)
# Out:
# 10

# %%
#make it as a dataFrame for further use
gpaStats = pd.DataFrame(
    {'course': cogsMajor,
     'maxGpa': maxGpa,
     'minGpa': minGpa
    })

# %%
# Setting the positions and width for the bars
pos = list(range(len(gpaStats['course'])))
width = 0.3

# Plotting the bars
fig, ax = plt.subplots(figsize=(20,7))

# Create a bar with gpa data,
# in position pos,
plt.bar(pos, gpaStats['maxGpa'], width, alpha=0.5, color='#EE3224', label=gpaStats['course'][0])
plt.bar([p + width for p in pos], gpaStats['minGpa'], width, alpha=0.5, color='#F78F1E', label=gpaStats['course'][1])

# Set the y axis label, title, and positions of x
ax.set_ylabel('GPA')
ax.set_title('Course GPA')
ax.set_xticks([p + 0.7 * width for p in pos])

# Set the labels for the x ticks
ax.set_xticklabels(gpaStats['course'])

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, max(gpaStats['maxGpa'] + gpaStats['minGpa'])] )

rects = ax.patches

#add number labels
for rect, label in zip(rects, gpaStats.maxGpa):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 0.2, label, ha='center', va='bottom')

rects = ax.patches
for rect, label in zip(rects, gpaStats.minGpa):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2 + 0.3, height - 0.4 , label, ha='center', va='bottom')

# Adding the legend and showing the plot
plt.legend(['maxGpa', 'minGpa'], loc='upper left')
plt.grid()
plt.show()

# %%
#do a comparison between maximum possible GPA and minimum possible GPA
avgMax = math.ceil(sum(maxGpa)/len(maxGpa) *100)/100
avgMin = math.ceil(sum(minGpa)/len(minGpa) *100)/100


comparison = [avgMax, avgMin]
freq_series = pd.Series.from_array(comparison) 
x_labels = ['maxGpa' + 'minGpa']

# now to plot the figure
plt.figure(figsize=(5, 5))
ax = freq_series.plot(kind='bar')
plt.ylim([0, 4.5] )

rects = ax.patches

for rect, label in zip(rects, comparison):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 0.1, label, ha='center', va='bottom')
    
objects = ('maxGpa', 'minGpa')
y_pos = np.arange(len(objects))
plt.xticks(y_pos, objects)
plt.ylabel('Cogs Major')
plt.title('GPA Difference')
plt.show()

# %% [markdown]
# ## Conclusions/Discussion

# %% [markdown]
# For the next few days, we aim to fully extract data from other majors and the respective required courses. After comparing data from within majors, we will compare data across majors and professors. We will have graphs displaying our data and a full analysis on how the professors who grade more strictly affect students' GPAs overall.
